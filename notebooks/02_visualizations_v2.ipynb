# %%
# Auto-reload setup
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))
from plotting_v2 import *

# %%
filepath = '../data/clean/exploitable/multiple_years.csv'
save_path = None
df = pd.read_csv(filepath, parse_dates=['MTU (CET/CEST)', 'Date'])

# %%
plot_smooth_prices(df, '2022/01/01', '2022/07/14', 15, save_path)
# plot_smooth_prices(df, '2023-02-01', '2024-07-14', 15)

# %%
# period = 'autumn'
period = ('01/02', '05/26')
period = 'spring'
period = ('01/02', '01/03')

plot_avg_hourly_prices(df, 2021, 2025, period, save_path)
# Out:
# 2021 OK
# 2022 OK
# 2023 OK
# 2024 OK
# 2025 OK

# %%
period = ('01/01', '12/31')
# period = 'autumn'
# period = 'summer'

plot_boxplots_by_weekday(df, 2021, 2024, period, save_path)

# %%
period = ('01/02', '05/26')
period = 'spring'
# period = 'spring'
# period = ('01/02', '01/03')

plot_heatmap(df, 2023, 2023, period, save_path)
