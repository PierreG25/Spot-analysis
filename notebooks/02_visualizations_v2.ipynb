# %%
# Auto-reload setup
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))
from plotting_visualization import *

# %%
filepath = '../data/clean/exploitable/merged_data.csv'
save_path = None
df = pd.read_csv(filepath, parse_dates=['Date'])

# %%
plot_smooth_prices(df, '2022/07/01', '2022/11/01', 5, save_path, inversed_style=False)
# plot_smooth_prices(df, '2023-02-01', '2024-07-14', 15)
# Out:
# 2022/06/26
# 2022/11/06
# 124
# 124
# 124
# ok
# c:\Users\VB6642\OneDrive - ENGIE\Desktop\Moi\PythonStuff\Spot-analysis\src\plotting_visualization.py:177: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()

# %% [markdown]
# As we can observe, the electricity prices are highly volatile.
# The first chart highlights the general trend of the prices by doing a rolling centered mean within window of numerous days. Thus, peaks can be found and linked to real events.
# On the other hand, the second chart details the volatility, by showing for each days of the considered time interval, the open, close, highest, and lowest prices.

# %%
plot_price_dist(df, '2023', '2024')
# Out:
# <class 'pandas.core.series.Series'>
# c:\Users\VB6642\OneDrive - ENGIE\Desktop\Moi\PythonStuff\Spot-analysis\src\plotting_visualization.py:196: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_dist = df.groupby('bin')[price_col].count()

# %%
# period = 'autumn'
period = ('01/02', '05/26')
period = 'spring'
period = ('01/02', '01/03')

plot_avg_hourly_prices(df, 2021, 2025, period, save_path)
# Out:
# 2021 OK
# 2022 OK
# 2023 OK
# 2024 OK
# 2025 OK

# %%
period = ('01/01', '12/31')
# period = 'autumn'
# period = 'summer'

boxplot(df, 'seasons', save_path)

# %%
period = ('01/02', '05/26')
period = 'spring'
# period = 'spring'
# period = ('01/02', '01/03')

plot_heatmap(df, 2023, 2023, period, save_path)
