# %%
# Auto-reload setup
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))
from plotting_v2 import *

# %%
filepath = '../data/clean/exploitable/multiple_years.csv'
df = pd.read_csv(filepath, parse_dates=['MTU (CET/CEST)', 'Date'])

# %%
plot_smooth_prices(df, '2022/03/01', '2025/07/14', 15)
# plot_smooth_prices(df, '2023-02-01', '2024-07-14', 15)

# %%
# period = 'autumn'
period = ('01/02', '05/26')
period = 'summer'
period = ('01/02', '01/03')

plot_avg_hourly_prices(df, 2023, 2023, period)
# Out:
#                      Day-ahead Price (EUR/MWh)       Date  Hour Weekday  Week  \
# MTU (CET/CEST)
# 2023-01-02 00:00:00                      61.38 2023-01-02     0  Monday     1
# 2023-01-02 01:00:00                      52.68 2023-01-02     1  Monday     1
# 2023-01-02 02:00:00                      52.93 2023-01-02     2  Monday     1
# 2023-01-02 03:00:00                      42.75 2023-01-02     3  Monday     1
# 2023-01-02 04:00:00                      50.08 2023-01-02     4  Monday     1
# 2023-01-02 05:00:00                      67.91 2023-01-02     5  Monday     1
# 2023-01-02 06:00:00                     105.08 2023-01-02     6  Monday     1
# 2023-01-02 07:00:00                     140.64 2023-01-02     7  Monday     1
# 2023-01-02 08:00:00                     149.80 2023-01-02     8  Monday     1
# 2023-01-02 09:00:00                     154.66 2023-01-02     9  Monday     1
# 2023-01-02 10:00:00                     145.61 2023-01-02    10  Monday     1
# 2023-01-02 11:00:00                     143.35 2023-01-02    11  Monday     1
# 2023-01-02 12:00:00                     144.38 2023-01-02    12  Monday     1
# 2023-01-02 13:00:00                     143.76 2023-01-02    13  Monday     1
# 2023-01-02 14:00:00                     148.20 2023-01-02    14  Monday     1
# 2023-01-02 15:00:00                     155.34 2023-01-02    15  Monday     1
# 2023-01-02 16:00:00                     163.17 2023-01-02    16  Monday     1
# 2023-01-02 17:00:00                     173.80 2023-01-02    17  Monday     1
# 2023-01-02 18:00:00                     174.74 2023-01-02    18  Monday     1
# 2023-01-02 19:00:00                     165.76 2023-01-02    19  Monday     1
# 2023-01-02 20:00:00                     153.00 2023-01-02    20  Monday     1
# 2023-01-02 21:00:00                     141.67 2023-01-02    21  Monday     1
# 2023-01-02 22:00:00                     134.91 2023-01-02    22  Monday     1
# 2023-01-02 23:00:00                     124.22 2023-01-02    23  Monday     1
#
#                      Month  Weekend
# MTU (CET/CEST)
# 2023-01-02 00:00:00      1    False
# 2023-01-02 01:00:00      1    False
# 2023-01-02 02:00:00      1    False
# 2023-01-02 03:00:00      1    False
# 2023-01-02 04:00:00      1    False
# 2023-01-02 05:00:00      1    False
# 2023-01-02 06:00:00      1    False
# 2023-01-02 07:00:00      1    False
# 2023-01-02 08:00:00      1    False
# 2023-01-02 09:00:00      1    False
# 2023-01-02 10:00:00      1    False
# 2023-01-02 11:00:00      1    False
# 2023-01-02 12:00:00      1    False
# 2023-01-02 13:00:00      1    False
# 2023-01-02 14:00:00      1    False
# 2023-01-02 15:00:00      1    False
# 2023-01-02 16:00:00      1    False
# 2023-01-02 17:00:00      1    False
# 2023-01-02 18:00:00      1    False
# 2023-01-02 19:00:00      1    False
# 2023-01-02 20:00:00      1    False
# 2023-01-02 21:00:00      1    False
# 2023-01-02 22:00:00      1    False
# 2023-01-02 23:00:00      1    False
# 2023 OK

# %%
period = ('01/01', '12/31')
# period = 'autumn'
# period = 'summer'

plot_boxplots_by_weekday(df, 2021, 2024, period)

# %%
period = ('01/02', '05/26')
period = 'spring'
# period = 'spring'
# period = ('01/02', '01/03')

plot_heatmap(df, 2022, 2022, period)
