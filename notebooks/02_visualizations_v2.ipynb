# %%
# Auto-reload setup
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))
from plotting_visualization import *

# %%
filepath = '../data/clean/exploitable/merged_data.csv'
save_path = None
df = pd.read_csv(filepath, parse_dates=['Date'])

# %%
plot_smooth_prices(df, '2022/07/01', '2022/11/01', 10, save_path)
# plot_smooth_prices(df, '2023-02-01', '2024-07-14', 15)
# Out:
# 2022/06/21
# 2022/11/11
# 124
# 124
# 124
# ok
# <string>:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot_price_dist(df, '2023', '2024')
# Out:
# <class 'pandas.core.series.Series'>
# /Users/gonot/Desktop/Energy project/epex-spot-analysis/src/plotting_visualization.py:192: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   binned_dist = df.groupby('bin')[price_col].count()

# %%
# period = 'autumn'
period = ('01/02', '05/26')
period = 'spring'
period = ('01/02', '01/03')

plot_avg_hourly_prices(df, 2021, 2025, period, save_path)
# Out:
# 2021 OK
# 2022 OK
# 2023 OK
# 2024 OK
# 2025 OK

# %%
period = ('01/01', '12/31')
# period = 'autumn'
# period = 'summer'

boxplot(df, 'weekdays', save_path)

# %%
period = ('01/02', '05/26')
period = 'spring'
# period = 'spring'
# period = ('01/02', '01/03')

plot_heatmap(df, 2023, 2023, period, save_path)
